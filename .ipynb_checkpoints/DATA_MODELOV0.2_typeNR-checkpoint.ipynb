# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Estructuras = pd.read_csv("colombia-data/Input1_clientes_estructura.csv", sep=";")
Ventas = pd.read_csv("colombia-data/Input2_clientes_venta.csv", sep=";")

# %%
Estructuras.head()
# Out:
#    Cliente   Regional2   Gerencia2   SubCanal2    Categoria  Nevera
# 0        1  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       0
# 1        2  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       0
# 2        3  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       0
# 3        4  Regional 1  Gerencia_1  Subcanal_1  Categoria_1       1
# 4        5  Regional 1  Gerencia_1  Subcanal_1  Categoria_2       1

# %%
Ventas.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2   Marca2   Cupo2    CapacidadEnvase2  \
# 0  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_1  CapacidadEnvase_12
# 1  2019    5       10  SegmentoPrecio_1  Marca_2  Cupo_2  CapacidadEnvase_10
# 2  2019    5       10  SegmentoPrecio_2  Marca_3  Cupo_2  CapacidadEnvase_10
# 3  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_2  CapacidadEnvase_16
# 4  2019    5       10  SegmentoPrecio_1  Marca_4  Cupo_2  CapacidadEnvase_10
#
#     Volumen       disc          nr
# 0  0.112229 -30.590603  900.328567
# 1  0.021734   0.000000  149.184463
# 2  0.043469   0.000000  359.625828
# 3  0.026345 -31.065261  134.748399
# 4  0.086938   0.000000  496.901005

# %%
df = pd.merge(Ventas, Estructuras, on='Cliente')
df.head()
# Out:
#     Año  Mes  Cliente   SegmentoPrecio2   Marca2   Cupo2    CapacidadEnvase2  \
# 0  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_1  CapacidadEnvase_12
# 1  2019    5       10  SegmentoPrecio_1  Marca_2  Cupo_2  CapacidadEnvase_10
# 2  2019    5       10  SegmentoPrecio_2  Marca_3  Cupo_2  CapacidadEnvase_10
# 3  2019    5       10  SegmentoPrecio_1  Marca_1  Cupo_2  CapacidadEnvase_16
# 4  2019    5       10  SegmentoPrecio_1  Marca_4  Cupo_2  CapacidadEnvase_10
#
#     Volumen       disc          nr   Regional2   Gerencia2   SubCanal2  \
# 0  0.112229 -30.590603  900.328567  Regional 1  Gerencia_3  Subcanal_1
# 1  0.021734   0.000000  149.184463  Regional 1  Gerencia_3  Subcanal_1
# 2  0.043469   0.000000  359.625828  Regional 1  Gerencia_3  Subcanal_1
# 3  0.026345 -31.065261  134.748399  Regional 1  Gerencia_3  Subcanal_1
# 4  0.086938   0.000000  496.901005  Regional 1  Gerencia_3  Subcanal_1
#
#      Categoria  Nevera
# 0  Categoria_2       1
# 1  Categoria_2       1
# ...

# %%
df.shape
# Out:
# (1406116, 15)

# %%
df.corr()
# Out:
#               Año       Mes   Cliente   Volumen      disc        nr    Nevera
# Año      1.000000 -0.560091  0.120095 -0.017009  0.029145 -0.015549 -0.061021
# Mes     -0.560091  1.000000 -0.006054  0.018006 -0.020459  0.018725 -0.000745
# Cliente  0.120095 -0.006054  1.000000  0.003562 -0.004041  0.003257 -0.155080
# Volumen -0.017009  0.018006  0.003562  1.000000 -0.646511  0.981551  0.045606
# disc     0.029145 -0.020459 -0.004041 -0.646511  1.000000 -0.601817 -0.028533
# nr      -0.015549  0.018725  0.003257  0.981551 -0.601817  1.000000  0.045386
# Nevera  -0.061021 -0.000745 -0.155080  0.045606 -0.028533  0.045386  1.000000

# %%
plt.matshow(df.corr())

# %%
Marcas = ['Marca_20', 'Marca_16', 'Marca_9', 'Marca_38', 'Marca_39']

# %%
df2 = df[df['Marca2'].isin(Marcas)]

# %%
df.shape
# Out:
# (1406116, 15)

# %%
df2
# Out:
#           Año  Mes  Cliente   SegmentoPrecio2    Marca2   Cupo2  \
# 41       2019    9       10  SegmentoPrecio_3   Marca_9  Cupo_3
# 50       2019   10       10  SegmentoPrecio_3   Marca_9  Cupo_3
# 75       2020    1       10  SegmentoPrecio_3   Marca_9  Cupo_3
# 78       2020    2       10  SegmentoPrecio_3   Marca_9  Cupo_3
# 94       2019   12       10  SegmentoPrecio_3   Marca_9  Cupo_3
# ...       ...  ...      ...               ...       ...     ...
# 1406111  2020    8    20577  SegmentoPrecio_3  Marca_39  Cupo_2
# 1406112  2020    7    20580  SegmentoPrecio_1  Marca_38  Cupo_2
# 1406113  2020    7    20580  SegmentoPrecio_3  Marca_39  Cupo_2
# 1406114  2020    9    20580  SegmentoPrecio_1  Marca_38  Cupo_2
# 1406115  2020    9    20580  SegmentoPrecio_3  Marca_39  Cupo_2
#
#            CapacidadEnvase2   Volumen        disc           nr   Regional2  \
# 41       CapacidadEnvase_12  0.037410  -27.511153   595.371853  Regional 1
# ...
