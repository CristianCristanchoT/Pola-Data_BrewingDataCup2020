# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from scipy import stats

# %%
clientes_estructura = pd.read_csv("DATA/Input1_clientes_estructura.csv", sep=";")
clientes_venta = pd.read_csv("DATA/Input2_clientes_venta.csv", sep=";")

# %%
file_csv = 'DATA/full_clientes_venta.csv'
full_clientes_venta = pd.read_csv(file_csv)
full_clientes_venta
# Out:
#           Año  Mes  Cliente  SegmentoPrecio2  Marca2  Cupo2  CapacidadEnvase2  \
# 0        2019    5       10                1       1      1                12
# 1        2019    5       10                1       2      2                10
# 2        2019    5       10                2       3      2                10
# 3        2019    5       10                1       1      2                16
# 4        2019    5       10                1       4      2                10
# ...       ...  ...      ...              ...     ...    ...               ...
# 1406111  2020    8    20577                3      39      2                10
# 1406112  2020    7    20580                1      38      2                10
# 1406113  2020    7    20580                3      39      2                10
# 1406114  2020    9    20580                1      38      2                10
# 1406115  2020    9    20580                3      39      2                10
#
#           Volumen       disc          nr  Regional2  Gerencia2  SubCanal2  \
# 0        0.112229 -30.590603  900.328567          1          3          1
# 1        0.021734   0.000000  149.184463          1          3          1
# 2        0.043469   0.000000  359.625828          1          3          1
# 3        0.026345 -31.065261  134.748399          1          3          1
# 4        0.086938   0.000000  496.901005          1          3          1
# ...           ...        ...         ...        ...        ...        ...
# 1406111  0.039122   0.000000  544.150314          1          8          3
# 1406112  0.000000   0.000000    0.000000          1         10          5
# 1406113  0.058683   0.000000  759.218996          1         10          5
# 1406114  0.000000   0.000000    0.000000          1         10          5
# 1406115  0.019561   0.000000  269.150196          1         10          5
#
#          Categoria  Nevera
# 0                2       1
# 1                2       1
# 2                2       1
# 3                2       1
# 4                2       1
# ...            ...     ...
# 1406111          2       0
# 1406112          6       0
# 1406113          6       0
# 1406114          6       0
# 1406115          6       0
#
# [1406116 rows x 15 columns]
